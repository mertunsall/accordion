# %%
import json
seeds = [0,1,2]

# %% [markdown]
# ## TEMPLATE

# %%
config_template = [{
    "name": "Random",
    "seed": SEED,
    "base_path": None,
    "save_path": None,
    "device_id": SEED,
    "exp_type": None, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": None,
    "train_size": None,
    "val_size": None,
    "depth": None,
    "num_classes": None,
    "beta": None,
    "lr": None,
    "n_devices": None,
    "n_device_per_round": None,
    "global_epochs": None,
    "scheduling": False,
    "distillation": False,
    "patience": None,
    "local_epochs": None,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": None,
    "device_num_blocks": None,
    "block_probabilities": None,
    "train_nums": None,
    "val_nums": None,
    "patch_size": 4,
    "max_len": 100,
    "embed_dim": 512,
    "num_classes": 10,
    "layers": 6,
    "channels": 3,
    "heads": 16,
} for SEED in seeds]
'''
for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)
'''
# Out:
# '\nfor config in config_template:\n    with open(f"exp_configs/{config[\'name\']}.json", \'w\') as f:\n        json.dump(config, f, indent=4)\n'

# %% [markdown]
# # CIFAR10

# %% [markdown]
# ## Centralized
#
# Status =

# %%
exp_id = 0
exp_type = "Centralized"
num_classes = 10
dataset = f"CIFAR{num_classes}"
patch_size = 4
max_len = 100
embed_dim = 512
num_classes = 10
layers = 6
channels = 3
heads = 16


config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ViT{layers}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/model',
    "device_id": SEED,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": None,
    "num_classes": 10,
    "beta": 0,
    "lr": 3e-3,
    "n_devices": None,
    "n_device_per_round": None,
    "global_epochs": 400,
    "scheduling": False,
    "distillation": False,
    "patience": 10,
    "local_epochs": None,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": None,
    "device_num_blocks": None,
    "block_probabilities": None,
    "train_nums": None,
    "val_nums": None,
    "patch_size": patch_size,
    "max_len": max_len,
    "embed_dim": embed_dim,
    "num_classes": num_classes,
    "layers": layers,
    "channels": channels,
    "heads": heads,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## Centralized Accordion
#
# Status:

# %%
exp_id = 0
exp_type = "CentralizedAccordion"
num_classes = 10
dataset = f"CIFAR{num_classes}"
patch_size = 4
max_len = 100
embed_dim = 512
num_classes = 10
layers = 6
channels = 3
heads = 16

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ViT{layers}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/model',
    "device_id": SEED,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": None,
    "num_classes": 10,
    "beta": 0,
    "lr": 3e-3,
    "n_devices": None,
    "n_device_per_round": None,
    "global_epochs": 400,
    "scheduling": False,
    "distillation": False,
    "patience": 10,
    "local_epochs": None,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": None,
    "device_num_blocks": None,
    "block_probabilities": layers*[0.5/layers] + [0.5],
    "train_nums": None,
    "val_nums": None,
    "patch_size": patch_size,
    "max_len": max_len,
    "embed_dim": embed_dim,
    "num_classes": num_classes,
    "layers": layers,
    "channels": channels,
    "heads": heads,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## Centralized Accordion with Distillation
#
# Status: Done!

# %%
exp_id = 0
exp_type = "CentralizedDistillAccordion"
num_classes = 10
dataset = f"CIFAR{num_classes}"
patch_size = 4
max_len = 100
embed_dim = 512
num_classes = 10
layers = 6
channels = 3
heads = 16


config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ViT{layers}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/model',
    "device_id": SEED,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": None,
    "num_classes": 10,
    "beta": 0.1,
    "lr": 3e-3,
    "n_devices": None,
    "n_device_per_round": None,
    "global_epochs": 400,
    "scheduling": False,
    "distillation": True,
    "patience": 15,
    "local_epochs": None,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": None,
    "device_num_blocks": None,
    "block_probabilities": layers*[0.5/layers] + [0.5],
    "train_nums": None,
    "val_nums": None,
    "patch_size": patch_size,
    "max_len": max_len,
    "embed_dim": embed_dim,
    "num_classes": num_classes,
    "layers": layers,
    "channels": channels,
    "heads": heads,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## Centralized Small Model
#
# Status: Done!

# %%
exp_id = 0
exp_type = "CentralizedSmall"
num_classes = 10
dataset = f"CIFAR{num_classes}"
patch_size = 4
max_len = 100
embed_dim = 512
num_classes = 10
layers = 6
channels = 3
heads = 16
n_blocks = 1


config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ViT{layers}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/model',
    "device_id": SEED,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": None,
    "num_classes": 10,
    "beta": 0,
    "lr": 3e-3,
    "n_devices": None,
    "n_device_per_round": None,
    "global_epochs": 400,
    "scheduling": False,
    "distillation": False,
    "patience": 10,
    "local_epochs": None,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": n_blocks,
    "num_blocks": None,
    "device_num_blocks": None,
    "block_probabilities": None,
    "train_nums": None,
    "val_nums": None,
    "patch_size": patch_size,
    "max_len": max_len,
    "embed_dim": embed_dim,
    "num_classes": num_classes,
    "layers": layers,
    "channels": channels,
    "heads": heads,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## Fed
#
# Status: Done

# %%
exp_id = 0
exp_type = "Fed"
num_classes = 10
dataset = f"CIFAR{num_classes}"
patch_size = 4
max_len = 100
embed_dim = 512
layers = 6
channels = 3
heads = 16
device_num_blocks = 10 * [6] 
for i in range(2):
    device_num_blocks += [5,4,3,2,1]


config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ViT{layers}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/model',
    "device_id": SEED,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": None,
    "num_classes": num_classes,
    "beta": 0,
    "lr": 5e-4,
    "n_devices": 20,
    "n_device_per_round": 20,
    "global_epochs": 300,
    "scheduling": False,
    "distillation": False,
    "patience": 10,
    "local_epochs": 10,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": [6]*20,
    "device_num_blocks": device_num_blocks,
    "block_probabilities": None,
    "train_nums": None,
    "val_nums": None,
    "patch_size": patch_size,
    "max_len": max_len,
    "embed_dim": embed_dim,
    "num_classes": num_classes,
    "layers": layers,
    "channels": channels,
    "heads": heads,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## FedAccordion
#
# Status: Done

# %%
exp_id = 0
exp_type = "FedAccordion"
num_classes = 10
dataset = f"CIFAR{num_classes}"
patch_size = 4
max_len = 100
embed_dim = 512
layers = 6
channels = 3
heads = 16
device_num_blocks = 10 * [6] 
for i in range(2):
    device_num_blocks += [5,4,3,2,1]


config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ViT{layers}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/model',
    "device_id": SEED+3,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": None,
    "num_classes": num_classes,
    "beta": 0,
    "lr": 1e-5,
    "n_devices": 20,
    "n_device_per_round": 20,
    "global_epochs": 300,
    "scheduling": False,
    "distillation": False,
    "patience": 10,
    "local_epochs": 10,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": device_num_blocks,
    "device_num_blocks": device_num_blocks,
    "block_probabilities": None,
    "train_nums": None,
    "val_nums": None,
    "patch_size": patch_size,
    "max_len": max_len,
    "embed_dim": embed_dim,
    "num_classes": num_classes,
    "layers": layers,
    "channels": channels,
    "heads": heads,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## FedClass
#
# Status: Done

# %%
exp_id = 0
exp_type = "FedClass"
dataset = "CIFAR10"
depth = 56
n_models = 8
confs = [27,25,23,21,18,16,12,8]
n_device_confs = [6] + 7*[2]
num_blocks = [[confs[i]]*n_device_confs[i] for i in range(n_models)]
train_size = 45000
val_size = 5000
train_nums = [(train_size*3)//10] + 7*[train_size//10]
val_nums = [(val_size*3)//10] + 7*[val_size//10]

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ResNet{depth}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/model',
    "device_id": SEED+3,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": depth,
    "num_classes": 10,
    "beta": 0,
    "lr": 0.05,
    "n_devices": 20,
    "n_device_per_round": 20,
    "global_epochs": 75,
    "scheduling": False,
    "distillation": False,
    "patience": 10,
    "local_epochs": 10,
    "n_models": n_models,
    "confs": confs,
    "n_device_confs": n_device_confs,
    "n_blocks": None,
    "num_blocks": num_blocks,
    "device_num_blocks": device_num_blocks,
    "fraction_probabilities": None,
    "train_nums": train_nums,
    "val_nums": val_nums,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## FedSmall
#
# Status: Done

# %%
exp_id = 0
exp_type = "FedSmall"
dataset = "CIFAR10"
depth = 56
device_num_blocks = 6 * [27] 
for i in range(2):
    device_num_blocks += [25,23,21,18,16,12,8]
n_blocks = 8
num_blocks = [8]*20

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ResNet{depth}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/model',
    "device_id": SEED + 3,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": depth,
    "num_classes": 10,
    "beta": 0,
    "lr": 0.05,
    "n_devices": 20,
    "n_device_per_round": 20,
    "global_epochs": 75,
    "scheduling": False,
    "distillation": False,
    "patience": 10,
    "local_epochs": 10,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": n_blocks,
    "num_blocks": num_blocks,
    "device_num_blocks": num_blocks,
    "fraction_probabilities": None,
    "train_nums": None,
    "val_nums": None,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## FedDistillAccordion
#
# Status: In Progress

# %%
exp_id = 0
exp_type = "FedDistillAccordion"
dataset = "CIFAR10"
depth = 56
device_num_blocks = 6 * [27] 
for i in range(2):
    device_num_blocks += [25,23,21,18,16,12,8]

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ResNet{depth}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/model',
    "device_id": SEED,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": depth,
    "num_classes": 10,
    "beta": 0.2,
    "lr": 0.05,
    "n_devices": 20,
    "n_device_per_round": 20,
    "global_epochs": 100,
    "scheduling": False,
    "distillation": True,
    "patience": 12,
    "local_epochs": 10,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": device_num_blocks,
    "device_num_blocks": device_num_blocks,
    "fraction_probabilities": None,
    "train_nums": None,
    "val_nums": None,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## FedDistillAccordion2
#
# Status: In Progress

# %%
exp_id = 1
exp_type = "FedDistillAccordion"
dataset = "CIFAR10"
depth = 56
device_num_blocks = 6 * [27] 
for i in range(2):
    device_num_blocks += [25,23,21,18,16,12,8]

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ResNet{depth}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}_{exp_id}ResNet{depth}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}_{exp_id}ResNet{depth}_{SEED}/model',
    "device_id": SEED+3,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": depth,
    "num_classes": 10,
    "beta": 0.4,
    "lr": 0.05,
    "n_devices": 20,
    "n_device_per_round": 20,
    "global_epochs": 100,
    "scheduling": False,
    "distillation": True,
    "patience": 12,
    "local_epochs": 10,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": device_num_blocks,
    "device_num_blocks": device_num_blocks,
    "fraction_probabilities": None,
    "train_nums": None,
    "val_nums": None,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## FedDistillAccordion3
#
# Status: In Progress

# %%
exp_id = 2
exp_type = "FedDistillAccordion"
dataset = "CIFAR10"
depth = 56
device_num_blocks = 6 * [27] 
for i in range(2):
    device_num_blocks += [25,23,21,18,16,12,8]

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ResNet{depth}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/model',
    "device_id": SEED,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": depth,
    "num_classes": 10,
    "beta": 1,
    "lr": 0.05,
    "n_devices": 20,
    "n_device_per_round": 20,
    "global_epochs": 100,
    "scheduling": False,
    "distillation": True,
    "patience": 12,
    "local_epochs": 10,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": device_num_blocks,
    "device_num_blocks": device_num_blocks,
    "fraction_probabilities": None,
    "train_nums": None,
    "val_nums": None,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# # CIFAR100

# %% [markdown]
# ## Centralized
#
# Status: Done!

# %%
exp_id = 0
exp_type = "Centralized"
num_classes = 100
dataset = f"CIFAR{num_classes}"
patch_size = 4
max_len = 100
embed_dim = 512
layers = 6
channels = 3
heads = 16


config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ViT{layers}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/model',
    "device_id": SEED ,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": None,
    "num_classes": 10,
    "beta": 0,
    "lr": 3e-3,
    "n_devices": None,
    "n_device_per_round": None,
    "global_epochs": 400,
    "scheduling": False,
    "distillation": False,
    "patience": 10,
    "local_epochs": None,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": None,
    "device_num_blocks": None,
    "block_probabilities": None,
    "train_nums": None,
    "val_nums": None,
    "patch_size": patch_size,
    "max_len": max_len,
    "embed_dim": embed_dim,
    "num_classes": num_classes,
    "layers": layers,
    "channels": channels,
    "heads": heads,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## Centralized Accordion
#
# Status: Done

# %%
exp_id = 0
exp_type = "CentralizedAccordion"
num_classes = 100
dataset = f"CIFAR{num_classes}"
patch_size = 4
max_len = 100
embed_dim = 512
layers = 6
channels = 3
heads = 16

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ViT{layers}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ViT{layers}_{SEED}/model',
    "device_id": SEED + 1,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": None,
    "num_classes": 10,
    "beta": 0,
    "lr": 3e-3,
    "n_devices": None,
    "n_device_per_round": None,
    "global_epochs": 400,
    "scheduling": False,
    "distillation": False,
    "patience": 10,
    "local_epochs": None,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": None,
    "device_num_blocks": None,
    "block_probabilities": layers*[0.5/layers] + [0.5],
    "train_nums": None,
    "val_nums": None,
    "patch_size": patch_size,
    "max_len": max_len,
    "embed_dim": embed_dim,
    "num_classes": num_classes,
    "layers": layers,
    "channels": channels,
    "heads": heads,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## Centralized Accordion with Distillation
#
# Status: Done (Tuning)

# %%
exp_id = 0
exp_type = "CentralizedDistillAccordion"
dataset = "CIFAR100"
depth = 56

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ResNet{depth}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/model',
    "device_id": SEED,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": depth,
    "num_classes": 100,
    "beta": 0.05,
    "lr": 0.05,
    "n_devices": None,
    "n_device_per_round": None,
    "global_epochs": 180,
    "scheduling": False,
    "distillation": True,
    "patience": 12,
    "local_epochs": None,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": None,
    "device_num_blocks": None,
    "fraction_probabilities": [0.5/27]*27 + [0.5] ,
    "train_nums": None,
    "val_nums": None,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## Centralized Small Model
#
# Status: Done

# %%
exp_id = 0
exp_type = "CentralizedSmall"
dataset = "CIFAR100"
depth = 56
n_blocks = 12

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ResNet{depth}_{n_blocks}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{n_blocks}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{n_blocks}_{SEED}/model',
    "device_id": SEED+3,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": depth,
    "num_classes": 100,
    "beta": 0,
    "lr": 0.1,
    "n_devices": None,
    "n_device_per_round": None,
    "global_epochs": 180,
    "scheduling": True,
    "distillation": False,
    "patience": 10,
    "local_epochs": None,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": n_blocks,
    "num_blocks": None,
    "device_num_blocks": None,
    "fraction_probabilities": None,
    "train_nums": None,
    "val_nums": None,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## Fed
#
# Status: In Progress

# %%
exp_id = 0
exp_type = "Fed"
dataset = "CIFAR100"
depth = 56
device_num_blocks = 6 * [27] 
for i in range(2):
    device_num_blocks += [25,23,21,18,16,12,8]

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ResNet{depth}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/model',
    "device_id": SEED,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": depth,
    "num_classes": 100,
    "beta": 0,
    "lr": 0.05,
    "n_devices": 20,
    "n_device_per_round": 20,
    "global_epochs": 90,
    "scheduling": False,
    "distillation": False,
    "patience": 10,
    "local_epochs": 10,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": [27]*20,
    "device_num_blocks": device_num_blocks,
    "fraction_probabilities": None,
    "train_nums": None,
    "val_nums": None,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## FedAccordion
#
# Status: In Progress

# %%
exp_id = 0
exp_type = "FedAccordion"
dataset = "CIFAR100"
depth = 56
device_num_blocks = 6 * [27] 
for i in range(2):
    device_num_blocks += [25,23,21,18,16,12,8]

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ResNet{depth}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/model',
    "device_id": SEED+3,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": depth,
    "num_classes": 100,
    "beta": 0,
    "lr": 0.05,
    "n_devices": 20,
    "n_device_per_round": 20,
    "global_epochs": 75,
    "scheduling": False,
    "distillation": False,
    "patience": 12,
    "local_epochs": 10,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": device_num_blocks,
    "device_num_blocks": device_num_blocks,
    "fraction_probabilities": None,
    "train_nums": None,
    "val_nums": None,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## FedClass
#
# Status: In Progress

# %%
exp_id = 0
exp_type = "FedClass"
dataset = "CIFAR100"
depth = 56
n_models = 8
confs = [27,25,23,21,18,16,12,8]
n_device_confs = [6] + 7*[2]
num_blocks = [[confs[i]]*n_device_confs[i] for i in range(n_models)]
train_size = 45000
val_size = 5000
train_nums = [(train_size*3)//10] + 7*[train_size//10]
val_nums = [(val_size*3)//10] + 7*[val_size//10]

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ResNet{depth}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/model',
    "device_id": SEED+3,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": depth,
    "num_classes": 100,
    "beta": 0,
    "lr": 0.05,
    "n_devices": 20,
    "n_device_per_round": 20,
    "global_epochs": 75,
    "scheduling": False,
    "distillation": False,
    "patience": 10,
    "local_epochs": 10,
    "n_models": n_models,
    "confs": confs,
    "n_device_confs": n_device_confs,
    "n_blocks": None,
    "num_blocks": num_blocks,
    "device_num_blocks": device_num_blocks,
    "fraction_probabilities": None,
    "train_nums": train_nums,
    "val_nums": val_nums,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## FedSmall
#
# Status: In Progress

# %%
exp_id = 0
exp_type = "FedSmall"
dataset = "CIFAR100"
depth = 56
device_num_blocks = 6 * [27] 
for i in range(2):
    device_num_blocks += [25,23,21,18,16,12,8]
n_blocks = 8
num_blocks = [8]*20

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ResNet{depth}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/model',
    "device_id": SEED,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": depth,
    "num_classes": 100,
    "beta": 0,
    "lr": 0.05,
    "n_devices": 20,
    "n_device_per_round": 20,
    "global_epochs": 75,
    "scheduling": False,
    "distillation": False,
    "patience": 10,
    "local_epochs": 10,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": n_blocks,
    "num_blocks": num_blocks,
    "device_num_blocks": num_blocks,
    "fraction_probabilities": None,
    "train_nums": None,
    "val_nums": None,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## FedDistillAccordion
#
# Status: In Progress

# %%
exp_id = 0
exp_type = "FedDistillAccordion"
dataset = "CIFAR100"
depth = 56
device_num_blocks = 6 * [27] 
for i in range(2):
    device_num_blocks += [25,23,21,18,16,12,8]

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ResNet{depth}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}ResNet{depth}_{SEED}/model',
    "device_id": SEED,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": depth,
    "num_classes": 100,
    "beta": 0.5,
    "lr": 0.05,
    "n_devices": 20,
    "n_device_per_round": 20,
    "global_epochs": 150,
    "scheduling": False,
    "distillation": True,
    "patience": 12,
    "local_epochs": 10,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": device_num_blocks,
    "device_num_blocks": device_num_blocks,
    "fraction_probabilities": None,
    "train_nums": None,
    "val_nums": None,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## FedDistillAccordion2
#
# Status: In Progress

# %%
exp_id = 1
exp_type = "FedDistillAccordion"
dataset = "CIFAR100"
depth = 56
device_num_blocks = 6 * [27] 
for i in range(2):
    device_num_blocks += [25,23,21,18,16,12,8]

config_template = [{
    "name": f"{exp_type}_{exp_id}-{dataset}-ResNet{depth}_{SEED}",
    "seed": SEED,
    "base_path": f'saved_models/{dataset}/{exp_type}_{exp_id}ResNet{depth}_{SEED}/',
    "save_path": f'saved_models/{dataset}/{exp_type}_{exp_id}ResNet{depth}_{SEED}/model',
    "device_id": SEED,
    "exp_type": exp_type, 
    # Centralized, CentralizedAccordion, CentralizedDistillAccordion, CentralizedSmall 
    # Fed, FedAccordion, FedDistillAccordion, FedClass, FedSmall
    "dataset": dataset,
    "train_size": 45000,
    "val_size": 5000,
    "depth": depth,
    "num_classes": 100,
    "beta": 1,
    "lr": 0.05,
    "n_devices": 20,
    "n_device_per_round": 20,
    "global_epochs": 150,
    "scheduling": False,
    "distillation": True,
    "patience": 12,
    "local_epochs": 10,
    "n_models": None,
    "confs": None,
    "n_device_confs": None,
    "n_blocks": None,
    "num_blocks": device_num_blocks,
    "device_num_blocks": device_num_blocks,
    "fraction_probabilities": None,
    "train_nums": None,
    "val_nums": None,

} for SEED in seeds]

for config in config_template:
    with open(f"exp_configs/{config['name']}.json", 'w') as f:
        json.dump(config, f, indent=4)

# %% [markdown]
# ## Transformers
